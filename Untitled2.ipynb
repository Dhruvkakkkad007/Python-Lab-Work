# %%
import math

# %%
math.sqrt(4)
# Out:
# 2.0

# %%
import math,random

# %%
random.random()
# Out:
# 0.9081352022082086

# %%
math.sqrt(4)
# Out:
# 2.0

# %%
from math import *

# %%
sqrt(4)
# Out:
# 2.0

# %%
print(sqrt(9))
# Out:
# 3.0

# %%
from math import *
def sqrt():
 return "Hello"
print(sqrt())
# Out:
# Hello

# %%
print(sqrt(9))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 print(sqrt(9))
#
# TypeError: sqrt() takes 0 positional arguments but 1 was given

# %%
print(range(5))
# Out:
# range(0, 5)

# %%
random.randrange(1,10,2)
# Out:
# 7

# %%
t1 = tuple(range(1,15))

# %%
random.choices(t1, k = 3) #repeated
# Out:
# [10, 9, 3]

# %%
import datetime

# %%
td = datetime.date.today()

# %%
td
# Out:
# datetime.date(2026, 3, 20)

# %%
t1 = datetime.datetime(7,12,12,23,2)

# %%
df = td + datetime.timedelta(hours=1)

# %%
print(df)
# Out:
# 2026-03-20

# %%
class Maths:
    def add(self,*args): #using variable length arguments
        return args

# %% [markdown]
# m1 =  Maths()

# %%
m1 = Maths()

# %%
m1.add()
# Out:
# ()

# %%
m1.add(10,20,30,40,60,80,90,100,101,0,1,2,3,5,6,)
# Out:
# (10, 20, 30, 40, 60, 80, 90, 100, 101, 0, 1, 2, 3, 5, 6)
